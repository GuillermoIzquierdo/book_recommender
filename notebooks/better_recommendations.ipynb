# %%
liked_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
csv_book_mapping['0']
# Out:
# '34684622'

# %%
# !wc -l goodreads_interactions.csv
# Out:
# wc: goodreads_interactions.csv: open: No such file or directory

# %%
# !ls -lh | grep goodreads_interactions.csv

# %%
overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

# %%
pd.read_csv('goodreads_interactions.csv', nrows = 100)
# Out:
#     user_id  book_id  is_read  rating  is_reviewed
# 0         0      948        1       5            0
# 1         0      947        1       5            1
# 2         0      946        1       5            0
# 3         0      945        1       5            0
# 4         0      944        1       5            0
# ..      ...      ...      ...     ...          ...
# 95        0      853        1       5            0
# 96        0      852        0       0            1
# 97        0      851        0       0            1
# 98        0      850        1       5            1
# 99        0      849        1       3            1
#
# [100 rows x 5 columns]

# %%
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#         user_id   book_id rating
# 0           284    977284      3
# 1           284    890054      4
# 2           284    837153      3
# 3           284   1586480      4
# 4           284     41814      5
# ...         ...       ...    ...
# 1530252  873216    127455      0
# 1530253  873216  10365343      0
# 1530254  873216  16131077      0
# 1530255  873216  18781576      0
# 1530256  873216     43615      0
#
# [1530257 rows x 3 columns]

# %%
top_recs = recs["book_id"].value_counts().head(10)

# %%
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  1333909                                        Good Harbor       10
# 1  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 2  6066819                               Best Friends Forever    51184
# 3   287140  Runic Astrology: Starcraft and Timekeeping in ...       15
# 4   287141                      The Aeneid for Boys and Girls       46
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287140.Run...
# 4  https://www.goodreads.com/book/show/287141.The...
#
#                                          cover_image  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1413219371m...
# 4  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                            mod_title
# 0                                        good harbor
# 1     the unschooled wizard sun wolf and starhawk 12
# 2                               best friends forever
# 3  runic astrology starcraft and timekeeping in t...
# 4                      the aeneid for boys and girls

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id                                              title  ratings  \
# 71398       77203                                    The Kite Runner  1848782
# 386663    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 546297       5107                             The Catcher in the Rye  2086945
# 630937       4671                                   The Great Gatsby  2758812
# 838525       5470                                               1984  2023937
# 1031472     38447                                The Handmaid's Tale   648783
# 1077226      2657                              To Kill a Mockingbird  3255518
# 1195873  18143977                        All the Light We Cannot See   498685
# 1196415         3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1446134  29983711                                           Pachinko     8161
#
#                                                        url  \
# 71398    https://www.goodreads.com/book/show/77203.The_...
# 386663   https://www.goodreads.com/book/show/2767052-th...
# 546297   https://www.goodreads.com/book/show/5107.The_C...
# 630937   https://www.goodreads.com/book/show/4671.The_G...
# 838525       https://www.goodreads.com/book/show/5470.1984
# 1031472  https://www.goodreads.com/book/show/38447.The_...
# 1077226  https://www.goodreads.com/book/show/2657.To_Ki...
# 1195873  https://www.goodreads.com/book/show/18143977-a...
# 1196415  https://www.goodreads.com/book/show/3.Harry_Po...
# 1446134  https://www.goodreads.com/book/show/29983711-p...
#
#                                                cover_image  \
# 71398    https://images.gr-assets.com/books/1484565687m...
# 386663   https://images.gr-assets.com/books/1447303603m...
# 546297   https://images.gr-assets.com/books/1398034300m...
# 630937   https://images.gr-assets.com/books/1490528560m...
# 838525   https://images.gr-assets.com/books/1348990566m...
# 1031472  https://images.gr-assets.com/books/1498057733m...
# 1077226  https://images.gr-assets.com/books/1361975680m...
# 1195873  https://images.gr-assets.com/books/1451445646m...
# 1196415  https://images.gr-assets.com/books/1474154022m...
# 1446134  https://images.gr-assets.com/books/1462393298m...
#
#                                                  mod_title
# 71398                                      the kite runner
# 386663                 the hunger games the hunger games 1
# 546297                              the catcher in the rye
# 630937                                    the great gatsby
# 838525                                                1984
# 1031472                                 the handmaids tale
# 1077226                              to kill a mockingbird
# 1195873                        all the light we cannot see
# 1196415  harry potter and the sorcerers stone harry pot...
# 1446134                                           pachinko

# %%
all_recs = recs["book_id"].value_counts()

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head(5)
# Out:
#     book_id  book_count
# 0   2767052        1092
# 1  29983711        1089
# 2      2657        1074
# 3         3        1048
# 4      4671        1028

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#         book_id  book_count  \
# 1      29983711        1089
# 7261   35069544          29
# 14752  29749094          15
# 238        4408         327
# 724     9317691         175
# 236    32920226         328
# 13156  36301023          17
# 13025  26857046          17
# 16306  35430702          14
# 216    30753987         342
#
#                                                    title  ratings  \
# 1                                               Pachinko     8161
# 7261   This Will Be My Undoing: Living at the Interse...        8
# 14752                            Superman (DC Icons, #4)        7
# 238                                         East of Eden     3447
# 724    The Name of the Wind (The Kingkiller Chronicle...     1043
# 236                                 Sing, Unburied, Sing     4592
# 13156                My Plain Jane (The Lady Janies, #2)       13
# 13025                 The Invisible Life of Addie La Rue       13
# 16306          The Lady's Guide to Petticoats and Piracy        9
# 216                                          The Leavers     5602
#
#                                                      url  \
# 1      https://www.goodreads.com/book/show/29983711-p...
# 7261   https://www.goodreads.com/book/show/35069544-t...
# 14752  https://www.goodreads.com/book/show/29749094-s...
# 238    https://www.goodreads.com/book/show/4408.East_...
# 724    https://www.goodreads.com/book/show/9317691-th...
# 236    https://www.goodreads.com/book/show/32920226-s...
# 13156  https://www.goodreads.com/book/show/36301023-m...
# 13025  https://www.goodreads.com/book/show/26857046-t...
# 16306  https://www.goodreads.com/book/show/35430702-t...
# 216    https://www.goodreads.com/book/show/30753987-t...
#
#                                              cover_image  \
# 1      https://images.gr-assets.com/books/1462393298m...
# 7261   https://images.gr-assets.com/books/1502099764m...
# 14752  https://s.gr-assets.com/assets/nophoto/book/11...
# 238    https://images.gr-assets.com/books/1323882457m...
# 724    https://images.gr-assets.com/books/1360558233m...
# 236    https://images.gr-assets.com/books/1499340866m...
# 13156  https://images.gr-assets.com/books/1507936746m...
# 13025  https://s.gr-assets.com/assets/nophoto/book/11...
# 16306  https://s.gr-assets.com/assets/nophoto/book/11...
# 216    https://images.gr-assets.com/books/1489158974m...
#
#                                                mod_title       score
# 1                                               pachinko  145.315648
# 7261   this will be my undoing living at the intersec...  105.125000
# 14752                                superman dc icons 4   32.142857
# 238                                         east of eden   31.020888
# 724      the name of the wind the kingkiller chronicle 1   29.362416
# 236                                   sing unburied sing   23.428571
# 13156                    my plain jane the lady janies 2   22.230769
# 13025                 the invisible life of addie la rue   22.230769
# 16306           the ladys guide to petticoats and piracy   21.777778
# 216                                          the leavers   20.878972

# %%
popular_recs = all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)


popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_844f9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >cover_image</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_844f9_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_844f9_row0_col0" class="data row0 col0" >32920226</td>
#       <td id="T_844f9_row0_col1" class="data row0 col1" >328</td>
#       <td id="T_844f9_row0_col2" class="data row0 col2" >Sing, Unburied, Sing</td>
#       <td id="T_844f9_row0_col3" class="data row0 col3" >4592</td>
#       <td id="T_844f9_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32920226-sing-unburied-sing">Goodreads</a></td>
#       <td id="T_844f9_row0_col5" class="data row0 col5" ><a href="https://images.gr-assets.com/books/1499340866m/32920226.jpg"><img src="https://images.gr-assets.com/books/1499340866m/32920226.jpg" width=50></img></a></td>
#       <td id="T_844f9_row0_col6" class="data row0 col6" >sing unburied sing</td>
#       <td id="T_844f9_row0_col7" class="data row0 col7" >23.428571</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row1" class="row_heading level0 row1" >216</th>
#       <td id="T_844f9_row1_col0" class="data row1 col0" >30753987</td>
#       <td id="T_844f9_row1_col1" class="data row1 col1" >342</td>
#       <td id="T_844f9_row1_col2" class="data row1 col2" >The Leavers</td>
#       <td id="T_844f9_row1_col3" class="data row1 col3" >5602</td>
#       <td id="T_844f9_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30753987-the-leavers">Goodreads</a></td>
#       <td id="T_844f9_row1_col5" class="data row1 col5" ><a href="https://images.gr-assets.com/books/1489158974m/30753987.jpg"><img src="https://images.gr-assets.com/books/1489158974m/30753987.jpg" width=50></img></a></td>
#       <td id="T_844f9_row1_col6" class="data row1 col6" >the leavers</td>
#       <td id="T_844f9_row1_col7" class="data row1 col7" >20.878972</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row2" class="row_heading level0 row2" >441</th>
#       <td id="T_844f9_row2_col0" class="data row2 col0" >33253215</td>
#       <td id="T_844f9_row2_col1" class="data row2 col1" >236</td>
#       <td id="T_844f9_row2_col2" class="data row2 col2" >The Heart's Invisible Furies</td>
#       <td id="T_844f9_row2_col3" class="data row2 col3" >3629</td>
#       <td id="T_844f9_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33253215-the-heart-s-invisible-furies">Goodreads</a></td>
#       <td id="T_844f9_row2_col5" class="data row2 col5" ><a href="https://images.gr-assets.com/books/1490803456m/33253215.jpg"><img src="https://images.gr-assets.com/books/1490803456m/33253215.jpg" width=50></img></a></td>
#       <td id="T_844f9_row2_col6" class="data row2 col6" >the hearts invisible furies</td>
#       <td id="T_844f9_row2_col7" class="data row2 col7" >15.347479</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row3" class="row_heading level0 row3" >71</th>
#       <td id="T_844f9_row3_col0" class="data row3 col0" >30688435</td>
#       <td id="T_844f9_row3_col1" class="data row3 col1" >533</td>
#       <td id="T_844f9_row3_col2" class="data row3 col2" >Exit West</td>
#       <td id="T_844f9_row3_col3" class="data row3 col3" >21378</td>
#       <td id="T_844f9_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30688435-exit-west">Goodreads</a></td>
#       <td id="T_844f9_row3_col5" class="data row3 col5" ><a href="https://images.gr-assets.com/books/1477324680m/30688435.jpg"><img src="https://images.gr-assets.com/books/1477324680m/30688435.jpg" width=50></img></a></td>
#       <td id="T_844f9_row3_col6" class="data row3 col6" >exit west</td>
#       <td id="T_844f9_row3_col7" class="data row3 col7" >13.288848</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row4" class="row_heading level0 row4" >251</th>
#       <td id="T_844f9_row4_col0" class="data row4 col0" >32283423</td>
#       <td id="T_844f9_row4_col1" class="data row4 col1" >321</td>
#       <td id="T_844f9_row4_col2" class="data row4 col2" >American War</td>
#       <td id="T_844f9_row4_col3" class="data row4 col3" >7776</td>
#       <td id="T_844f9_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32283423-american-war">Goodreads</a></td>
#       <td id="T_844f9_row4_col5" class="data row4 col5" ><a href="https://images.gr-assets.com/books/1481494946m/32283423.jpg"><img src="https://images.gr-assets.com/books/1481494946m/32283423.jpg" width=50></img></a></td>
#       <td id="T_844f9_row4_col6" class="data row4 col6" >american war</td>
#       <td id="T_844f9_row4_col7" class="data row4 col7" >13.251157</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row5" class="row_heading level0 row5" >228</th>
#       <td id="T_844f9_row5_col0" class="data row5 col0" >26025588</td>
#       <td id="T_844f9_row5_col1" class="data row5 col1" >335</td>
#       <td id="T_844f9_row5_col2" class="data row5 col2" >Behold the Dreamers</td>
#       <td id="T_844f9_row5_col3" class="data row5 col3" >8793</td>
#       <td id="T_844f9_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/26025588-behold-the-dreamers">Goodreads</a></td>
#       <td id="T_844f9_row5_col5" class="data row5 col5" ><a href="https://images.gr-assets.com/books/1439643293m/26025588.jpg"><img src="https://images.gr-assets.com/books/1439643293m/26025588.jpg" width=50></img></a></td>
#       <td id="T_844f9_row5_col6" class="data row5 col6" >behold the dreamers</td>
#       <td id="T_844f9_row5_col7" class="data row5 col7" >12.762993</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row6" class="row_heading level0 row6" >345</th>
#       <td id="T_844f9_row6_col0" class="data row6 col0" >17912498</td>
#       <td id="T_844f9_row6_col1" class="data row6 col1" >266</td>
#       <td id="T_844f9_row6_col2" class="data row6 col2" >The Queen of the Night</td>
#       <td id="T_844f9_row6_col3" class="data row6 col3" >6115</td>
#       <td id="T_844f9_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17912498-the-queen-of-the-night">Goodreads</a></td>
#       <td id="T_844f9_row6_col5" class="data row6 col5" ><a href="https://images.gr-assets.com/books/1460425080m/17912498.jpg"><img src="https://images.gr-assets.com/books/1460425080m/17912498.jpg" width=50></img></a></td>
#       <td id="T_844f9_row6_col6" class="data row6 col6" >the queen of the night</td>
#       <td id="T_844f9_row6_col7" class="data row6 col7" >11.570891</td>
#     </tr>
#     <tr>
#       <th id="T_844f9_level0_row7" class="row_heading level0 row7" >325</th>
#       <td id="T_844f9_row7_col0" class="data row7 col0" >28114515</td>
#       <td id="T_844f9_row7_col1" class="data row7 col1" >276</td>
#       <td id="T_844f9_row7_col2" class="data row7 col2" >The Wangs vs. the World</td>
#       <td id="T_844f9_row7_col3" class="data row7 col3" >7044</td>
#       <td id="T_844f9_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/28114515-the-wangs-vs-the-world">Goodreads</a></td>
#       <td id="T_844f9_row7_col5" class="data row7 col5" ><a href="https://images.gr-assets.com/books/1451493647m/28114515.jpg"><img src="https://images.gr-assets.com/books/1451493647m/28114515.jpg" width=50></img></a></td>
#       <td id="T_844f9_row7_col6" class="data row7 col6" >the wangs vs the world</td>
#       <td id="T_844f9_row7_col7" class="data row7 col7" >10.814310</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
pd.read_csv('book_id_map.csv')
# Out:
#          book_id_csv   book_id
# 0                  0  34684622
# 1                  1  34536488
# 2                  2  34017076
# 3                  3     71730
# 4                  4  30422361
# ...              ...       ...
# 2360645      2360645  19517100
# 2360646      2360646  18597299
# 2360647      2360647  18584882
# 2360648      2360648  18518801
# 2360649      2360649  18518607
#
# [2360650 rows x 2 columns]

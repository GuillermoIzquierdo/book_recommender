# %% [markdown]
# # Books

# %%
import pandas as pd
import gzip
with gzip.open("/Users/diegocristobal/code/dieg9906/book_recommender/book_recommender/data/goodreads_books.json.gz","r") as f:
    line= f.readline()

# %%
import json

# %%
json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields_book(line):
    data=json.loads(line)
    return{
        
        "book_id":data["book_id"],
        "title":data["title_without_series"],
        "ratings":data["ratings_count"],
        "url":data["url"],
        "cover_img":data["image_url"],
        "isbn":data["isbn"],
        "authors":data["authors"],
        "description":data["description"]
        
        
    }

# %% [markdown]
# Get rid of unnecesary columns and books with less than 15 reviews

# %%
books_titles=[]
with gzip.open("/Users/diegocristobal/code/dieg9906/book_recommender/book_recommender/data/goodreads_books.json.gz","r") as f:
    while True:
        line=f.readline()
        if not line:
            break
        fields=parse_fields_book(line)
        
        try:
            ratings=int(fields["ratings"])
        except ValueError:
            continue
        if ratings>150:
            books_titles.append(fields)

# %% [markdown]
# Put our data into a Dataframe

# %%
titles=pd.DataFrame.from_dict(books_titles)

# %%
titles
# Out:
#          book_id                                              title ratings  \
# 0        6066819                               Best Friends Forever   51184
# 1         287149                               The Devil's Notebook     986
# 2        6066814          Crowner Royal (Crowner John Mystery, #13)     186
# 3       33394837            The House of Memory (Pluto's Snitch #2)     269
# 4          89375  90 Minutes in Heaven: A True Story of Death an...   68157
# ...          ...                                                ...     ...
# 381185  17280727                                       دولة البطاطس     151
# 381186  31522515                                Walking on My Grave     340
# 381187  15500943                Not Quickly Broken (Chop, Chop, #7)     456
# 381188   1370179             The Brazilian Boss's Innocent Mistress     240
# 381189  17805813                      Ondine (Ondine Quartet, #0.5)     327
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/6066819-be...
# 1       https://www.goodreads.com/book/show/287149.The...
# 2       https://www.goodreads.com/book/show/6066814-cr...
# 3       https://www.goodreads.com/book/show/33394837-t...
# 4       https://www.goodreads.com/book/show/89375.90_M...
# ...                                                   ...
# 381185       https://www.goodreads.com/book/show/17280727
# 381186  https://www.goodreads.com/book/show/31522515-w...
# 381187  https://www.goodreads.com/book/show/15500943-n...
# 381188  https://www.goodreads.com/book/show/1370179.Th...
# 381189  https://www.goodreads.com/book/show/17805813-o...
#
#                                                 cover_img        isbn  \
# 0       https://s.gr-assets.com/assets/nophoto/book/11...  0743294297
# 1       https://images.gr-assets.com/books/1328768789m...  0922915113
# 2       https://images.gr-assets.com/books/1328724803m...  184737297X
# 3       https://images.gr-assets.com/books/1493114742m...
# 4       https://s.gr-assets.com/assets/nophoto/book/11...  0800759494
# ...                                                   ...         ...
# 381185  https://images.gr-assets.com/books/1358953155m...
# 381186  https://images.gr-assets.com/books/1490374478m...
# 381187  https://images.gr-assets.com/books/1381765124m...
# 381188  https://s.gr-assets.com/assets/nophoto/book/11...  0373126646
# 381189  https://images.gr-assets.com/books/1379766592m...
#
#                                                   authors  \
# 0                     [{'author_id': '9212', 'role': ''}]
# 1       [{'author_id': '2983296', 'role': ''}, {'autho...
# 2                    [{'author_id': '37778', 'role': ''}]
# 3                   [{'author_id': '242185', 'role': ''}]
# 4       [{'author_id': '39054', 'role': ''}, {'author_...
# ...                                                   ...
# 381185             [{'author_id': '6479249', 'role': ''}]
# 381186             [{'author_id': '4278425', 'role': ''}]
# 381187             [{'author_id': '1995264', 'role': ''}]
# 381188               [{'author_id': '45898', 'role': ''}]
# 381189             [{'author_id': '4633056', 'role': ''}]
#
#                                               description
# 0       Addie Downs and Valerie Adler were eight when ...
# 1       Wisdom, humor, and dark observations by the fo...
# 2       London, 1196. At the command of Richard the Li...
# 3
# 4       As he is driving home from a minister's confer...
# ...                                                   ...
# 381185  mdh lw 'tk ywm bHytk wknt mHSran byn mDyin wms...
# 381186  In the latest Death on Demand Mystery from the...
# 381187  While romance has always been a strong part of...
# 381188  Deep in the Brazilian rainforest lies a rich a...
# 381189  "I shouldn't get involved."\nRebellious and he...
#
# [381190 rows x 8 columns]

# %%
titles["title"] = titles["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True)

# %%
titles["title"] = titles["title"].str.replace("[^(\w+ ?)*$]", "", regex=True)

# %%
titles["title"]
# Out:
# 0                                      Best Friends Forever
# 1                                       The Devils Notebook
# 2                     Crowner Royal Crowner John Mystery 13
# 3                       The House of Memory Plutos Snitch 2
# 4         90 Minutes in Heaven A True Story of Death and...
#                                 ...
# 381185
# 381186                                  Walking on My Grave
# 381187                       Not Quickly Broken Chop Chop 7
# 381188                The Brazilian Bosss Innocent Mistress
# 381189                             Ondine Ondine Quartet 05
# Name: title, Length: 381190, dtype: object

# %%
titles.to_csv("/Users/diegocristobal/code/dieg9906/book_recommender/book_recommender/data/books_withdesc.csv")
titles.

# %%
titles_ratings=pd.to_numeric(titles["ratings"])

# %%
# !pwd

# %%
df_reviews = pd.read_csv('../data/goodreads_interactions.csv', nrows=1000)

# %%
df_reviews

# %%
import pandas as pd

def get_books_data():
    #return pd.read_csv("gs://data_for_api_again/books_info_books_cleaned.csv")
    return pd.read_parquet("../data/books_info_books_cleaned.parquet")

# %%
results = get_books_data()

# %%
results.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  book_id  \
# 0             0           0  6066819
# 1             1           1   287149
# 2             2           2  6066814
# 3             4           4    89375
# 4             5           5    89376
#
#                                                title  ratings  \
# 0                               Best Friends Forever    51184
# 1                               The Devil's Notebook      986
# 2          Crowner Royal (Crowner John Mystery, #13)      186
# 3  90 Minutes in Heaven: A True Story of Death an...    68157
# 4                                             Heaven     7345
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/6066819-be...
# 1  https://www.goodreads.com/book/show/287149.The...
# 2  https://www.goodreads.com/book/show/6066814-cr...
# 3  https://www.goodreads.com/book/show/89375.90_M...
# 4   https://www.goodreads.com/book/show/89376.Heaven
#
#                                            cover_img        isbn  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...  0743294297
# 1  https://images.gr-assets.com/books/1328768789m...  0922915113
# 2  https://images.gr-assets.com/books/1328724803m...  184737297X
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  0800759494
# 4  https://images.gr-assets.com/books/1406508230m...  0842379428
#
#                                              authors  \
# 0                [{'author_id': '9212', 'role': ''}]
# 1  [{'author_id': '2983296', 'role': ''}, {'autho...
# 2               [{'author_id': '37778', 'role': ''}]
# 3  [{'author_id': '39054', 'role': ''}, {'author_...
# 4                [{'author_id': '4862', 'role': ''}]
#
#                                          description  \
# 0  Addie Downs and Valerie Adler were eight when ...
# 1  Wisdom, humor, and dark observations by the fo...
# 2  London, 1196. At the command of Richard the Li...
# 3  As he is driving home from a minister's confer...
# 4  What is Heaven really going to be like? What w...
#
#                                            mod_title  \
# 0                               best friends forever
# 1                                the devils notebook
# 2              crowner royal crowner john mystery 13
# 3  90 minutes in heaven a true story of death and...
# 4                                             heaven
#
#                                             mod_desc
# 0  down eight first meet decide best forever wake...
# 1  wisdom humor dark founder church satan ponder ...
# 2  command lionheart sir de leave beloved west co...
# 3  drive home minister conference minister piper ...
# 4  heaven really go like look like wont heaven ge...

# %%
dictionary = {'title': results['title'][0], 'image': results['cover_img'][0], 'book_id': results['book_id'][0], 'url': results['url'][0], 'description': results['description'][0]}

# %%
dictionary
# Out:
# {'title': 'Best Friends Forever',
#  'image': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png',
#  'book_id': 6066819,
#  'url': 'https://www.goodreads.com/book/show/6066819-best-friends-forever',
#  'description': "Addie Downs and Valerie Adler were eight when they first met and decided to be best friends forever. But, in the wake of tragedy and betrayal during their teenage years, everything changed. Val went on to fame and fortune. Addie stayed behind in their small Midwestern town. Destiny, however, had more in store for these two. And when, twenty-five years later, Val shows up at Addie's front door with blood on her coat and terror on her face, it is the beginning of a wild adventure for two women joined by love and history who find strength together that they could not find alone."}

# %%
json = {'book 1': {'title': results['title'][0], 'image': results['cover_img'][0], 'book_id': results['book_id'][0], 'url': results['url'][0], 'description': results['description'][0]},
            'book 2': {'title': results['title'][1], 'image': results['cover_img'][1], 'book_id': results['book_id'][1], 'url': results['url'][1], 'description': results['description'][1]},
            'book 3': {'title': results['title'][2], 'image': results['cover_img'][2], 'book_id': results['book_id'][2], 'url': results['url'][2], 'description': results['description'][2]},
            'book 4': {'title': results['title'][3], 'image': results['cover_img'][3], 'book_id': results['book_id'][3], 'url': results['url'][3], 'description': results['description'][3]},
            'book 5': {'title': results['title'][4], 'image': results['cover_img'][4], 'book_id': results['book_id'][4], 'url': results['url'][4], 'description': results['description'][4]}}

# %%
json
# Out:
# {'book 1': {'title': 'Best Friends Forever',
#   'image': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png',
#   'book_id': 6066819,
#   'url': 'https://www.goodreads.com/book/show/6066819-best-friends-forever',
#   'description': "Addie Downs and Valerie Adler were eight when they first met and decided to be best friends forever. But, in the wake of tragedy and betrayal during their teenage years, everything changed. Val went on to fame and fortune. Addie stayed behind in their small Midwestern town. Destiny, however, had more in store for these two. And when, twenty-five years later, Val shows up at Addie's front door with blood on her coat and terror on her face, it is the beginning of a wild adventure for two women joined by love and history who find strength together that they could not find alone."},
#  'book 2': {'title': "The Devil's Notebook",
#   'image': 'https://images.gr-assets.com/books/1328768789m/287149.jpg',
#   'book_id': 287149,
#   'url': 'https://www.goodreads.com/book/show/287149.The_Devil_s_Notebook',
#   'description': 'Wisdom, humor, and dark observations by the founder of the Church of Satan. LaVey ponders such topics as nonconformity, occult faddism, erotic politics, the "Goodguy badge," demoralization and the construction of artificial human companions.'},
#  'book 3': {'title': 'Crowner Royal (Crowner John Mystery, #13)',
#   'image': 'https://images.gr-assets.com/books/1328724803m/6066814.jpg',
#   'book_id': 6066814,
#   'url': 'https://www.goodreads.com/book/show/6066814-crowner-royal',
#   'description': "London, 1196. At the command of Richard the Lionheart, Sir John de Wolfe has left his beloved West Country for the Palace of Westminster, where he has been appointed Coroner of the Verge. But with the king overseas, embroiled in a costly war against King Philip of France, Sir John is dismayed to discover that the English court is a hotbed of greed, corruption and petty in-fighting.\nThe murder of one of the palace clerks, stabbed in broad daylight and thrown into the River Thames, leads John to suspect that there's a conspiracy underway to overthrow King Richard. And with the visit of the dowager Queen Eleanor fast approaching, the new Coroner must risk his life to prove his suspicions are right, root out the traitors within and prevent a national catastrophe."},
#  'book 4': {'title': '90 Minutes in Heaven: A True Story of Death and Life',
#   'image': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png',
#   'book_id': 89375,
#   'url': 'https://www.goodreads.com/book/show/89375.90_Minutes_in_Heaven',
#   'description': "As he is driving home from a minister's conference, Baptist minister Don Piper collides with a semi-truck that crosses into his lane. He is pronounced dead at the scene. For the next 90 minutes, Piper experiences heaven where he is greeted by those who had influenced him spiritually. He hears beautiful music and feels true peace. Back on earth, a passing minister who had also been at the conference is led to pray for Don even though he knows the man is dead. Piper miraculously comes back to life and the bliss of heaven is replaced by a long and painful recovery. For years Piper kept his heavenly experience to himself. Finally, however, friends and family convinced him to share his remarkable story."},
#  'book 5': {'title': 'Heaven',
#   'image': 'https://images.gr-assets.com/books/1406508230m/89376.jpg',
#   'book_id': 89376,
#   'url': 'https://www.goodreads.com/book/show/89376.Heaven',
#   'description': 'What is Heaven really going to be like? What will we look like? What will we do? Won\'t Heaven get boring after a while?\nWe all have questions about what Heaven will be like, and after 25 years of extensive research, Dr. Randy Alcorn has the answers.\nIn the most comprehensive and definitive book on Heaven to date, Randy invites you to picture Heaven the way Scripture describes it-- a bright, vibrant, and physical New Earth, free from sin, suffering, and death, and brimming with Christ\'s presence, wondrous natural beauty, and the richness of human culture as God intended it.\nGod has put eternity in our hearts. Now, Randy Alcorn brings eternity to light in a way that will surprise you, spark your imagination, and change how you live life today.\nIf you\'ve always thought of Heaven as a realm of disembodied spirits, clouds, and eternal harp strumming, you\'re in for a wonderful surprise.\nThis is a book about real people with real bodies enjoying close relationships with God and each other, eating, drinking, working, playing, traveling, worshiping, and discovering on a New Earth. Earth as God created it. Earth as he intended it to be.\nAnd the next time you hear someone say, "We cant begin to imagine what Heaven will be like," you\'ll be able to tell them, "I can."'}}

# %%
import pandas as pd
import numpy as np

# %%
options = ["Heaven", "Best Friends Forever"]

# %%
books_id = results[results["title"].isin(options)]

# %%
books_id
# Out:
#         Unnamed: 0.1  Unnamed: 0   book_id                 title  ratings  \
# 0                  0           0   6066819  Best Friends Forever    51184
# 4                  5           5     89376                Heaven     7345
# 101447        166384      166384  25604483  Best Friends Forever      671
# 104039        170638      170638  12735319                Heaven      978
# 181538        297310      297310   7014718  Best Friends Forever      183
# 212673        348392      348392   6723239  Best Friends Forever      713
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/6066819-be...
# 4        https://www.goodreads.com/book/show/89376.Heaven
# 101447  https://www.goodreads.com/book/show/25604483-b...
# 104039  https://www.goodreads.com/book/show/12735319-h...
# 181538  https://www.goodreads.com/book/show/7014718-be...
# 212673  https://www.goodreads.com/book/show/6723239-be...
#
#                                                 cover_img        isbn  \
# 0       https://s.gr-assets.com/assets/nophoto/book/11...  0743294297
# 4       https://images.gr-assets.com/books/1406508230m...  0842379428
# 101447  https://images.gr-assets.com/books/1443651265m...  1455526088
# 104039  https://images.gr-assets.com/books/1337274639m...  1408314665
# 181538  https://images.gr-assets.com/books/1394992096m...  1439165491
# 212673  https://images.gr-assets.com/books/1403346805m...  0743294300
#
#                                       authors  \
# 0         [{'author_id': '9212', 'role': ''}]
# 4         [{'author_id': '4862', 'role': ''}]
# 101447   [{'author_id': '84220', 'role': ''}]
# 104039  [{'author_id': '624389', 'role': ''}]
# 181538    [{'author_id': '9212', 'role': ''}]
# 212673    [{'author_id': '9212', 'role': ''}]
#
#                                               description  \
# 0       Addie Downs and Valerie Adler were eight when ...
# 4       What is Heaven really going to be like? What w...
# 101447  Angry arguments between Celine Richardson and ...
# 104039  The night that Heaven lost her heart was cold ...
# 181538  From New York Times bestselling author Jennife...
# 212673  Addie Downs and Valerie Adler will be best fri...
#
#                    mod_title  \
# 0       best friends forever
# 4                     heaven
# 101447  best friends forever
# 104039                heaven
# 181538  best friends forever
# 212673  best friends forever
#
#                                                  mod_desc
# 0       down eight first meet decide best forever wake...
# 4       heaven really go like look like wont heaven ge...
# 101447  angry husband twelve become common past severa...
# 104039  night heaven lose heart cold moonless blade sl...
# 181538  new york time author come smart witty fairy ta...
# 212673  down best forever thats believe move across st...

# %%
results[results['title'] == options[0]]
# Out:
#         Unnamed: 0.1  Unnamed: 0   book_id   title  ratings  \
# 4                  5           5     89376  Heaven     7345
# 104039        170638      170638  12735319  Heaven      978
#
#                                                       url  \
# 4        https://www.goodreads.com/book/show/89376.Heaven
# 104039  https://www.goodreads.com/book/show/12735319-h...
#
#                                                 cover_img        isbn  \
# 4       https://images.gr-assets.com/books/1406508230m...  0842379428
# 104039  https://images.gr-assets.com/books/1337274639m...  1408314665
#
#                                       authors  \
# 4         [{'author_id': '4862', 'role': ''}]
# 104039  [{'author_id': '624389', 'role': ''}]
#
#                                               description mod_title  \
# 4       What is Heaven really going to be like? What w...    heaven
# 104039  The night that Heaven lost her heart was cold ...    heaven
#
#                                                  mod_desc
# 4       heaven really go like look like wont heaven ge...
# 104039  night heaven lose heart cold moonless blade sl...

# %%
book_ids = []
for option in options:
        book_id = results[results['title']==option].sort_values('ratings', ascending = False)['book_id'].head(1).values
        book_ids.append(book_ids)

book_ids
# Out:
# [[...], [...]]

# %%
pd.DataFrame(book_ids)
# Out:
#           4           104039     0           101447     181538     212673  \
# book_id  89376.0  12735319.0        NaN         NaN        NaN        NaN
# book_id      NaN         NaN  6066819.0  25604483.0  7014718.0  6723239.0
# book_id      NaN         NaN        NaN         NaN        NaN        NaN
#
#             2
# book_id        NaN
# book_id        NaN
# book_id  6066814.0

# %% [markdown]
# # Reviews

# %%
with gzip.open("/Users/diegocristobal/code/dieg9906/book_recommender/book_recommender/data/goodreads_reviews_dedup.json.gz","r") as f:
    line_review= f.readline()

# %%
line_review

# %%
def parse_fields_review(line_review):
    data_review=json.loads(line_review)
    return{
        
        "user_id":data_review["user_id"],
        "book_id":data_review["book_id"],
        "review_id":data_review["review_id"],
        "rating":data_review["rating"],
        "review_text":data_review["review_text"],
        "n_votes": data_review["n_votes"]
        
        
    }

# %%
# %%time
books_reviews=[]
with gzip.open("/Users/diegocristobal/code/dieg9906/book_recommender/book_recommender/data/goodreads_reviews_dedup.json.gz","r") as f:
    while True:
        line_review=f.readline()
        if not line_review:
            break
        fields=parse_fields_review(line_review)
        try:
            ratings=int(fields["rating"])
        except ValueError:
            continue
        try:
            n_votes=int(fields["n_votes"])
        except ValueError:
            continue    
        if n_votes>20:
            books_reviews.append(fields)
            if len(books_reviews) > 1000:
                break

# %%
books_reviews
